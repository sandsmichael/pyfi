# %%
import sys, os
sys.path.append(r"C:\Users\micha\OneDrive\Documents\code\pyfi\\")

from pyfi.base.retrievers import equity
from pyfi.analytics.time_series.stats.probability import Probability
from pyfi.analytics.time_series.stats.descriptive import Descriptive
from pyfi.core.timeseries import TimeSeries, Frequency, AggFunc

import pandas as pd
import numpy as np

# %%
df = equity.get_price_matrix(tickers = ['VTWO', 'SPY'], start_date='2023-01-01', end_date='2023-11-30')
# Out:
# [*********************100%%**********************]  2 of 2 completed

# %%
df.tail()
# Out:
#                    SPY       VTWO
# Date
# 2023-11-22  455.019989  72.040001
# 2023-11-24  455.299988  72.489998
# 2023-11-27  454.480011  72.290001
# 2023-11-28  454.929993  71.980003
# 2023-11-29  454.609985  72.360001

# %%
df = equity.get_return_matrix(tickers = ['VTWO', 'SPY'], start_date='2023-01-01', end_date='2023-11-30').multiply(100)
# Out:
# [*********************100%%**********************]  2 of 2 completed

# %%
prob = Probability(
    df = df,
)

# %%
prob.scenario_probabilites()
# Out:
# P(x)  -5.0    -4.5    -4.0    -3.5    -3.0    -2.5    -2.0    -1.5    -1.0
# SPY    0.0  0.0000  0.0000  0.0000  0.0001  0.0012  0.0072  0.0314  0.1017  \
# VTWO   0.0  0.0001  0.0006  0.0023  0.0076  0.0214  0.0521  0.1107  0.2058
#
# P(x)    -0.5  ...     0.5     1.0     1.5     2.0     2.5     3.0     3.5
# SPY   0.2470  ...  0.3111  0.1399  0.0475  0.0120  0.0022  0.0003  0.0000  \
# VTWO  0.3374  ...  0.3507  0.2162  0.1177  0.0561  0.0233  0.0084  0.0026
#
# P(x)     4.0     4.5   5.0
# SPY   0.0000  0.0000   0.0
# VTWO  0.0007  0.0002   0.0
#
# [2 rows x 22 columns]

# %%
prob.scenario_z_scores()
# Out:
# Z-score    -5.0    -4.5    -4.0    -3.5    -3.0    -2.5    -2.0    -1.5
# SPY     -5.9782 -5.3900 -4.8017 -4.2135 -3.6252 -3.0369 -2.4487 -1.8604  \
# VTWO    -4.0339 -3.6323 -3.2307 -2.8292 -2.4276 -2.0260 -1.6244 -1.2228
#
# Z-score    -1.0    -0.5  ...     0.5     1.0     1.5     2.0     2.5     3.0
# SPY     -1.2722 -0.6839  ...  0.4926  1.0809  1.6691  2.2574  2.8456  3.4339  \
# VTWO    -0.8212 -0.4196  ...  0.3835  0.7851  1.1867  1.5883  1.9899  2.3914
#
# Z-score     3.5     4.0     4.5     5.0
# SPY      4.0221  4.6104  5.1987  5.7869
# VTWO     2.7930  3.1946  3.5962  3.9978
#
# [2 rows x 22 columns]

# %%
Descriptive(df=df).describe()
# Out:
#                        SPY       VTWO
# 0.1              -1.122776  -1.486830
# 0.25             -0.441968  -0.932806
# 0.5               0.060090   0.020513
# 0.75              0.652022   0.926912
# 0.9               1.204070   1.374464
# mean              0.081305   0.022493
# median            0.060090   0.020513
# std               0.849968   1.245071
# var               0.722445   1.550201
# skew             -0.001088   0.303510
# kurtosis         -0.243343   0.957424
# excess kurtosis  -3.243343  -2.042576
# cv               10.454049  55.353763
# min              -2.006093  -2.949616
# max               2.293210   5.453210

# %%
ts = TimeSeries(
    df = df,
)

# %%
ts.group(frequency = Frequency.WEEKLY_F, aggfunc=np.sum)

# %%
Descriptive(df=ts.df).describe()
# Out:
#                       SPY       VTWO
# 0.1             -2.275706  -3.244158
# 0.25            -0.695814  -2.086860
# 0.5              0.482028  -0.055621
# 0.75             1.751285   1.996094
# 0.9              2.435817   3.785299
# mean             0.386199   0.106842
# median           0.482028  -0.055621
# std              1.910761   2.971225
# var              3.651008   8.828179
# skew            -0.099225  -0.011377
# kurtosis         0.622017   0.392093
# excess kurtosis -2.377983  -2.607907
# cv               4.947605  27.809627
# min             -4.588317  -8.276743
# max              5.718854   7.292929

# %%
from pyfi.analytics.time_series.stats.montecarlo import MonteCarlo
from pyfi.base.retrievers import equity

df = equity.get_price_matrix(tickers = ['VTWO'], start_date='2023-01-01', end_date='2023-11-30')

mc = MonteCarlo(prices = df, num_simulations = 1000, n_periods = 30)
simulated, full_simulation = mc.run()
mc.plot()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
mc.describe()
# Out:
#                  Simulation End Values
# 0.1                          66.086657
# 0.25                         69.150112
# 0.5                          72.092690
# 0.75                         75.306217
# 0.9                          78.177000
# mean                         72.259864
# median                       72.092690
# std                           4.736926
# var                          22.438465
# skew                          0.151921
# kurtosis                      0.085401
# excess kurtosis              -2.914599
# cv                            0.065554
# min                          59.013042
# max                          88.182679

# %%
from pyfi.base.retrievers import options
from pyfi.core.options.options import Chain, Contract, OptionType, OptionExposure

ticker = 'TLT'
target_date = '2023-12-31'

calls, puts = options.get_option_chain(ticker = ticker, date = target_date, strike_bounds=0.05)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
optc = Chain(ticker = ticker, chain = puts, option_type = OptionType.PUT, option_exposure = OptionExposure.SHORT, spot = 91.5)
optc.processed_chain
# optc.processed_chain.to_excel('chain.xlsx')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# {'price_ts': Date
# 2023-01-03    101.459999
# 2023-01-04    102.849998
# 2023-01-05    103.279999
# 2023-01-06    105.180000
# 2023-01-09    105.739998
#                  ...
# 2023-11-27     91.300003
# 2023-11-28     91.480003
# 2023-11-29     92.629997
# 2023-11-30     91.559998
# 2023-12-01     92.989998
# Name: Close, Length: 231, dtype: float64, 'df': Date
# 2023-01-03    101.459999
# 2023-01-04    102.849998
# 2023-01-05    103.279999
# 2023-01-06    105.180000
# 2023-01-09    105.739998
#                  ...
# 2023-11-27     91.300003
# 2023-11-28     91.480003
# 2023-11-29     92.629997
# 2023-11-30     91.559998
# 2023-12-01     92.989998
# Name: Close, Length: 231, dtype: float64, '_spot': 91.5, 'option_type': -1, 'option_exposure': <OptionExposure.SHORT: 'Bid'>, 'valuation': Date(2,12,2023), 'expiration': Date(29,12,2023), 'premium': 0.43, 'K': 89.0, 'ivol': 0.1814, 'contract_id': 'TLT231229P00089000', 'rfr': 0.05}
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 810640940.6523887
# Iteration:      2,   Func. Count:     14,   Neg. LLF: 980.4885926181186
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 625.0002907665598
# Iteration:      4,   Func. Count:     29,   Neg. LLF: 360.4202261059312
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 357.6957862893544
# Iteration:      6,   Func. Count:     41,   Neg. LLF: 357.69516255722084
# Iteration:      7,   Func. Count:     46,   Neg. LLF: 357.69515378734883
# Iteration:      8,   Func. Count:     51,   Neg. LLF: 357.6951530668287
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 357.6951530668287
#             Iterations: 8
#             Function evaluations: 51
#             Gradient evaluations: 8
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 810640940.6523887
# Iteration:      2,   Func. Count:     14,   Neg. LLF: 980.4885926181186
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 625.0002907665598
# Iteration:      4,   Func. Count:     29,   Neg. LLF: 360.4202261059312
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 357.6957862893544
# Iteration:      6,   Func. Count:     41,   Neg. LLF: 357.69516255722084
# Iteration:      7,   Func. Count:     46,   Neg. LLF: 357.69515378734883
# Iteration:      8,   Func. Count:     51,   Neg. LLF: 357.6951530668287
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 357.6951530668287
#             Iterations: 8
#             Function evaluations: 51
#             Gradient evaluations: 8
# [*********************100%%**********************]  1 of 1 completed
# {'price_ts': Date
# 2023-01-03    101.459999
# 2023-01-04    102.849998
# 2023-01-05    103.279999
# 2023-01-06    105.180000
# 2023-01-09    105.739998
#                  ...
# 2023-11-27     91.300003
# 2023-11-28     91.480003
# 2023-11-29     92.629997
# 2023-11-30     91.559998
# 2023-12-01     92.989998
# Name: Close, Length: 231, dtype: float64, 'df': Date
# 2023-01-03    101.459999
# 2023-01-04    102.849998
# 2023-01-05    103.279999
# 2023-01-06    105.180000
# 2023-01-09    105.739998
#                  ...
# 2023-11-27     91.300003
# 2023-11-28     91.480003
# 2023-11-29     92.629997
# 2023-11-30     91.559998
# 2023-12-01     92.989998
# Name: Close, Length: 231, dtype: float64, '_spot': 91.5, 'option_type': -1, 'option_exposure': <OptionExposure.SHORT: 'Bid'>, 'valuation': Date(2,12,2023), 'expiration': Date(29,12,2023), 'premium': 0.63, 'K': 90.0, 'ivol': 0.17800000000000002, 'contract_id': 'TLT231229P00090000', 'rfr': 0.05}
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 810640940.6523887
# Iteration:      2,   Func. Count:     14,   Neg. LLF: 980.4885926181186
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 625.0002907665598
# Iteration:      4,   Func. Count:     29,   Neg. LLF: 360.4202261059312
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 357.6957862893544
# Iteration:      6,   Func. Count:     41,   Neg. LLF: 357.69516255722084
# Iteration:      7,   Func. Count:     46,   Neg. LLF: 357.69515378734883
# Iteration:      8,   Func. Count:     51,   Neg. LLF: 357.6951530668287
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 357.6951530668287
#             Iterations: 8
#             Function evaluations: 51
#             Gradient evaluations: 8
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 810640940.6523887
# Iteration:      2,   Func. Count:     14,   Neg. LLF: 980.4885926181186
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 625.0002907665598
# Iteration:      4,   Func. Count:     29,   Neg. LLF: 360.4202261059312
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 357.6957862893544
# Iteration:      6,   Func. Count:     41,   Neg. LLF: 357.69516255722084
# Iteration:      7,   Func. Count:     46,   Neg. LLF: 357.69515378734883
# Iteration:      8,   Func. Count:     51,   Neg. LLF: 357.6951530668287
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 357.6951530668287
#             Iterations: 8
#             Function evaluations: 51
#             Gradient evaluations: 8
# [*********************100%%**********************]  1 of 1 completed
# {'price_ts': Date
# 2023-01-03    101.459999
# 2023-01-04    102.849998
# 2023-01-05    103.279999
# 2023-01-06    105.180000
# 2023-01-09    105.739998
#                  ...
# 2023-11-27     91.300003
# 2023-11-28     91.480003
# 2023-11-29     92.629997
# 2023-11-30     91.559998
# 2023-12-01     92.989998
# Name: Close, Length: 231, dtype: float64, 'df': Date
# 2023-01-03    101.459999
# 2023-01-04    102.849998
# 2023-01-05    103.279999
# 2023-01-06    105.180000
# 2023-01-09    105.739998
#                  ...
# 2023-11-27     91.300003
# 2023-11-28     91.480003
# 2023-11-29     92.629997
# 2023-11-30     91.559998
# 2023-12-01     92.989998
# Name: Close, Length: 231, dtype: float64, '_spot': 91.5, 'option_type': -1, 'option_exposure': <OptionExposure.SHORT: 'Bid'>, 'valuation': Date(2,12,2023), 'expiration': Date(29,12,2023), 'premium': 0.9, 'K': 91.0, 'ivol': 0.1751, 'contract_id': 'TLT231229P00091000', 'rfr': 0.05}
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 810640940.6523887
# Iteration:      2,   Func. Count:     14,   Neg. LLF: 980.4885926181186
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 625.0002907665598
# Iteration:      4,   Func. Count:     29,   Neg. LLF: 360.4202261059312
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 357.6957862893544
# Iteration:      6,   Func. Count:     41,   Neg. LLF: 357.69516255722084
# Iteration:      7,   Func. Count:     46,   Neg. LLF: 357.69515378734883
# Iteration:      8,   Func. Count:     51,   Neg. LLF: 357.6951530668287
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 357.6951530668287
#             Iterations: 8
#             Function evaluations: 51
#             Gradient evaluations: 8
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 810640940.6523887
# Iteration:      2,   Func. Count:     14,   Neg. LLF: 980.4885926181186
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 625.0002907665598
# Iteration:      4,   Func. Count:     29,   Neg. LLF: 360.4202261059312
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 357.6957862893544
# Iteration:      6,   Func. Count:     41,   Neg. LLF: 357.69516255722084
# Iteration:      7,   Func. Count:     46,   Neg. LLF: 357.69515378734883
# Iteration:      8,   Func. Count:     51,   Neg. LLF: 357.6951530668287
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 357.6951530668287
#             Iterations: 8
#             Function evaluations: 51
#             Gradient evaluations: 8
# [*********************100%%**********************]  1 of 1 completed
# {'price_ts': Date
# 2023-01-03    101.459999
# 2023-01-04    102.849998
# 2023-01-05    103.279999
# 2023-01-06    105.180000
# 2023-01-09    105.739998
#                  ...
# 2023-11-27     91.300003
# 2023-11-28     91.480003
# 2023-11-29     92.629997
# 2023-11-30     91.559998
# 2023-12-01     92.989998
# Name: Close, Length: 231, dtype: float64, 'df': Date
# 2023-01-03    101.459999
# 2023-01-04    102.849998
# 2023-01-05    103.279999
# 2023-01-06    105.180000
# 2023-01-09    105.739998
#                  ...
# 2023-11-27     91.300003
# 2023-11-28     91.480003
# 2023-11-29     92.629997
# 2023-11-30     91.559998
# 2023-12-01     92.989998
# Name: Close, Length: 231, dtype: float64, '_spot': 91.5, 'option_type': -1, 'option_exposure': <OptionExposure.SHORT: 'Bid'>, 'valuation': Date(2,12,2023), 'expiration': Date(29,12,2023), 'premium': 1.25, 'K': 92.0, 'ivol': 0.1724, 'contract_id': 'TLT231229P00092000', 'rfr': 0.05}
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 810640940.6523887
# Iteration:      2,   Func. Count:     14,   Neg. LLF: 980.4885926181186
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 625.0002907665598
# Iteration:      4,   Func. Count:     29,   Neg. LLF: 360.4202261059312
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 357.6957862893544
# Iteration:      6,   Func. Count:     41,   Neg. LLF: 357.69516255722084
# Iteration:      7,   Func. Count:     46,   Neg. LLF: 357.69515378734883
# Iteration:      8,   Func. Count:     51,   Neg. LLF: 357.6951530668287
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 357.6951530668287
#             Iterations: 8
#             Function evaluations: 51
#             Gradient evaluations: 8
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 810640940.6523887
# Iteration:      2,   Func. Count:     14,   Neg. LLF: 980.4885926181186
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 625.0002907665598
# Iteration:      4,   Func. Count:     29,   Neg. LLF: 360.4202261059312
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 357.6957862893544
# Iteration:      6,   Func. Count:     41,   Neg. LLF: 357.69516255722084
# Iteration:      7,   Func. Count:     46,   Neg. LLF: 357.69515378734883
# Iteration:      8,   Func. Count:     51,   Neg. LLF: 357.6951530668287
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 357.6951530668287
#             Iterations: 8
#             Function evaluations: 51
#             Gradient evaluations: 8
# [*********************100%%**********************]  1 of 1 completed
# {'price_ts': Date
# 2023-01-03    101.459999
# 2023-01-04    102.849998
# 2023-01-05    103.279999
# 2023-01-06    105.180000
# 2023-01-09    105.739998
#                  ...
# 2023-11-27     91.300003
# 2023-11-28     91.480003
# 2023-11-29     92.629997
# 2023-11-30     91.559998
# 2023-12-01     92.989998
# Name: Close, Length: 231, dtype: float64, 'df': Date
# 2023-01-03    101.459999
# 2023-01-04    102.849998
# 2023-01-05    103.279999
# 2023-01-06    105.180000
# 2023-01-09    105.739998
#                  ...
# 2023-11-27     91.300003
# 2023-11-28     91.480003
# 2023-11-29     92.629997
# 2023-11-30     91.559998
# 2023-12-01     92.989998
# Name: Close, Length: 231, dtype: float64, '_spot': 91.5, 'option_type': -1, 'option_exposure': <OptionExposure.SHORT: 'Bid'>, 'valuation': Date(2,12,2023), 'expiration': Date(29,12,2023), 'premium': 1.7, 'K': 93.0, 'ivol': 0.172, 'contract_id': 'TLT231229P00093000', 'rfr': 0.05}
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 810640940.6523887
# Iteration:      2,   Func. Count:     14,   Neg. LLF: 980.4885926181186
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 625.0002907665598
# Iteration:      4,   Func. Count:     29,   Neg. LLF: 360.4202261059312
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 357.6957862893544
# Iteration:      6,   Func. Count:     41,   Neg. LLF: 357.69516255722084
# Iteration:      7,   Func. Count:     46,   Neg. LLF: 357.69515378734883
# Iteration:      8,   Func. Count:     51,   Neg. LLF: 357.6951530668287
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 357.6951530668287
#             Iterations: 8
#             Function evaluations: 51
#             Gradient evaluations: 8
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 810640940.6523887
# Iteration:      2,   Func. Count:     14,   Neg. LLF: 980.4885926181186
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 625.0002907665598
# Iteration:      4,   Func. Count:     29,   Neg. LLF: 360.4202261059312
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 357.6957862893544
# Iteration:      6,   Func. Count:     41,   Neg. LLF: 357.69516255722084
# Iteration:      7,   Func. Count:     46,   Neg. LLF: 357.69515378734883
# Iteration:      8,   Func. Count:     51,   Neg. LLF: 357.6951530668287
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 357.6951530668287
#             Iterations: 8
#             Function evaluations: 51
#             Gradient evaluations: 8
# [*********************100%%**********************]  1 of 1 completed
# {'price_ts': Date
# 2023-01-03    101.459999
# 2023-01-04    102.849998
# 2023-01-05    103.279999
# 2023-01-06    105.180000
# 2023-01-09    105.739998
#                  ...
# 2023-11-27     91.300003
# 2023-11-28     91.480003
# 2023-11-29     92.629997
# 2023-11-30     91.559998
# 2023-12-01     92.989998
# Name: Close, Length: 231, dtype: float64, 'df': Date
# 2023-01-03    101.459999
# 2023-01-04    102.849998
# 2023-01-05    103.279999
# 2023-01-06    105.180000
# 2023-01-09    105.739998
#                  ...
# 2023-11-27     91.300003
# 2023-11-28     91.480003
# 2023-11-29     92.629997
# 2023-11-30     91.559998
# 2023-12-01     92.989998
# Name: Close, Length: 231, dtype: float64, '_spot': 91.5, 'option_type': -1, 'option_exposure': <OptionExposure.SHORT: 'Bid'>, 'valuation': Date(2,12,2023), 'expiration': Date(29,12,2023), 'premium': 2.27, 'K': 94.0, 'ivol': 0.17350000000000002, 'contract_id': 'TLT231229P00094000', 'rfr': 0.05}
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 810640940.6523887
# Iteration:      2,   Func. Count:     14,   Neg. LLF: 980.4885926181186
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 625.0002907665598
# Iteration:      4,   Func. Count:     29,   Neg. LLF: 360.4202261059312
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 357.6957862893544
# Iteration:      6,   Func. Count:     41,   Neg. LLF: 357.69516255722084
# Iteration:      7,   Func. Count:     46,   Neg. LLF: 357.69515378734883
# Iteration:      8,   Func. Count:     51,   Neg. LLF: 357.6951530668287
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 357.6951530668287
#             Iterations: 8
#             Function evaluations: 51
#             Gradient evaluations: 8
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 810640940.6523887
# Iteration:      2,   Func. Count:     14,   Neg. LLF: 980.4885926181186
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 625.0002907665598
# Iteration:      4,   Func. Count:     29,   Neg. LLF: 360.4202261059312
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 357.6957862893544
# Iteration:      6,   Func. Count:     41,   Neg. LLF: 357.69516255722084
# Iteration:      7,   Func. Count:     46,   Neg. LLF: 357.69515378734883
# Iteration:      8,   Func. Count:     51,   Neg. LLF: 357.6951530668287
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 357.6951530668287
#             Iterations: 8
#             Function evaluations: 51
#             Gradient evaluations: 8
# [*********************100%%**********************]  1 of 1 completed
# {'price_ts': Date
# 2023-01-03    101.459999
# 2023-01-04    102.849998
# 2023-01-05    103.279999
# 2023-01-06    105.180000
# 2023-01-09    105.739998
#                  ...
# 2023-11-27     91.300003
# 2023-11-28     91.480003
# 2023-11-29     92.629997
# 2023-11-30     91.559998
# 2023-12-01     92.989998
# Name: Close, Length: 231, dtype: float64, 'df': Date
# 2023-01-03    101.459999
# 2023-01-04    102.849998
# 2023-01-05    103.279999
# 2023-01-06    105.180000
# 2023-01-09    105.739998
#                  ...
# 2023-11-27     91.300003
# 2023-11-28     91.480003
# 2023-11-29     92.629997
# 2023-11-30     91.559998
# 2023-12-01     92.989998
# Name: Close, Length: 231, dtype: float64, '_spot': 91.5, 'option_type': -1, 'option_exposure': <OptionExposure.SHORT: 'Bid'>, 'valuation': Date(2,12,2023), 'expiration': Date(29,12,2023), 'premium': 2.92, 'K': 95.0, 'ivol': 0.1765, 'contract_id': 'TLT231229P00095000', 'rfr': 0.05}
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 810640940.6523887
# Iteration:      2,   Func. Count:     14,   Neg. LLF: 980.4885926181186
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 625.0002907665598
# Iteration:      4,   Func. Count:     29,   Neg. LLF: 360.4202261059312
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 357.6957862893544
# Iteration:      6,   Func. Count:     41,   Neg. LLF: 357.69516255722084
# Iteration:      7,   Func. Count:     46,   Neg. LLF: 357.69515378734883
# Iteration:      8,   Func. Count:     51,   Neg. LLF: 357.6951530668287
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 357.6951530668287
#             Iterations: 8
#             Function evaluations: 51
#             Gradient evaluations: 8
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 810640940.6523887
# Iteration:      2,   Func. Count:     14,   Neg. LLF: 980.4885926181186
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 625.0002907665598
# Iteration:      4,   Func. Count:     29,   Neg. LLF: 360.4202261059312
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 357.6957862893544
# Iteration:      6,   Func. Count:     41,   Neg. LLF: 357.69516255722084
# Iteration:      7,   Func. Count:     46,   Neg. LLF: 357.69515378734883
# Iteration:      8,   Func. Count:     51,   Neg. LLF: 357.6951530668287
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 357.6951530668287
#             Iterations: 8
#             Function evaluations: 51
#             Gradient evaluations: 8
# [*********************100%%**********************]  1 of 1 completed
# {'price_ts': Date
# 2023-01-03    101.459999
# 2023-01-04    102.849998
# 2023-01-05    103.279999
# 2023-01-06    105.180000
# 2023-01-09    105.739998
#                  ...
# 2023-11-27     91.300003
# 2023-11-28     91.480003
# 2023-11-29     92.629997
# 2023-11-30     91.559998
# 2023-12-01     92.989998
# Name: Close, Length: 231, dtype: float64, 'df': Date
# 2023-01-03    101.459999
# 2023-01-04    102.849998
# 2023-01-05    103.279999
# 2023-01-06    105.180000
# 2023-01-09    105.739998
#                  ...
# 2023-11-27     91.300003
# 2023-11-28     91.480003
# 2023-11-29     92.629997
# 2023-11-30     91.559998
# 2023-12-01     92.989998
# Name: Close, Length: 231, dtype: float64, '_spot': 91.5, 'option_type': -1, 'option_exposure': <OptionExposure.SHORT: 'Bid'>, 'valuation': Date(2,12,2023), 'expiration': Date(29,12,2023), 'premium': 3.65, 'K': 96.0, 'ivol': 0.1826, 'contract_id': 'TLT231229P00096000', 'rfr': 0.05}
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 810640940.6523887
# Iteration:      2,   Func. Count:     14,   Neg. LLF: 980.4885926181186
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 625.0002907665598
# Iteration:      4,   Func. Count:     29,   Neg. LLF: 360.4202261059312
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 357.6957862893544
# Iteration:      6,   Func. Count:     41,   Neg. LLF: 357.69516255722084
# Iteration:      7,   Func. Count:     46,   Neg. LLF: 357.69515378734883
# Iteration:      8,   Func. Count:     51,   Neg. LLF: 357.6951530668287
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 357.6951530668287
#             Iterations: 8
#             Function evaluations: 51
#             Gradient evaluations: 8
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 810640940.6523887
# Iteration:      2,   Func. Count:     14,   Neg. LLF: 980.4885926181186
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 625.0002907665598
# Iteration:      4,   Func. Count:     29,   Neg. LLF: 360.4202261059312
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 357.6957862893544
# Iteration:      6,   Func. Count:     41,   Neg. LLF: 357.69516255722084
# Iteration:      7,   Func. Count:     46,   Neg. LLF: 357.69515378734883
# Iteration:      8,   Func. Count:     51,   Neg. LLF: 357.6951530668287
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 357.6951530668287
#             Iterations: 8
#             Function evaluations: 51
#             Gradient evaluations: 8
# [*********************100%%**********************]  1 of 1 completed
# {'price_ts': Date
# 2023-01-03    101.459999
# 2023-01-04    102.849998
# 2023-01-05    103.279999
# 2023-01-06    105.180000
# 2023-01-09    105.739998
#                  ...
# 2023-11-27     91.300003
# 2023-11-28     91.480003
# 2023-11-29     92.629997
# 2023-11-30     91.559998
# 2023-12-01     92.989998
# Name: Close, Length: 231, dtype: float64, 'df': Date
# 2023-01-03    101.459999
# 2023-01-04    102.849998
# 2023-01-05    103.279999
# 2023-01-06    105.180000
# 2023-01-09    105.739998
#                  ...
# 2023-11-27     91.300003
# 2023-11-28     91.480003
# 2023-11-29     92.629997
# 2023-11-30     91.559998
# 2023-12-01     92.989998
# Name: Close, Length: 231, dtype: float64, '_spot': 91.5, 'option_type': -1, 'option_exposure': <OptionExposure.SHORT: 'Bid'>, 'valuation': Date(2,12,2023), 'expiration': Date(29,12,2023), 'premium': 4.45, 'K': 97.0, 'ivol': 0.1924, 'contract_id': 'TLT231229P00097000', 'rfr': 0.05}
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 810640940.6523887
# Iteration:      2,   Func. Count:     14,   Neg. LLF: 980.4885926181186
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 625.0002907665598
# Iteration:      4,   Func. Count:     29,   Neg. LLF: 360.4202261059312
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 357.6957862893544
# Iteration:      6,   Func. Count:     41,   Neg. LLF: 357.69516255722084
# Iteration:      7,   Func. Count:     46,   Neg. LLF: 357.69515378734883
# Iteration:      8,   Func. Count:     51,   Neg. LLF: 357.6951530668287
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 357.6951530668287
#             Iterations: 8
#             Function evaluations: 51
#             Gradient evaluations: 8
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 810640940.6523887
# Iteration:      2,   Func. Count:     14,   Neg. LLF: 980.4885926181186
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 625.0002907665598
# Iteration:      4,   Func. Count:     29,   Neg. LLF: 360.4202261059312
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 357.6957862893544
# Iteration:      6,   Func. Count:     41,   Neg. LLF: 357.69516255722084
# Iteration:      7,   Func. Count:     46,   Neg. LLF: 357.69515378734883
# Iteration:      8,   Func. Count:     51,   Neg. LLF: 357.6951530668287
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 357.6951530668287
#             Iterations: 8
#             Function evaluations: 51
#             Gradient evaluations: 8
#                         TLT231229P00089000     TLT231229P00090000
# Last Trade Date      2023-12-01 3:50PM EST  2023-12-01 3:45PM EST  \
# Strike                                89.0                   90.0
# Last Price                            0.48                   0.64
# Bid                                   0.43                   0.63
# Ask                                   0.46                   0.66
# Change                               -0.32                  -0.48
# % Change                           -40.00%                -42.86%
# Volume                                3602                   1080
# Open Interest                         3843                   4291
# Implied Volatility                  18.14%                 17.80%
# Expiration Date                 2023-12-29             2023-12-29
# Expiration_dt          2023-12-29 00:00:00    2023-12-29 00:00:00
# Market_IV                           0.1814                  0.178
# price_ts                               NaN                    NaN
# df                                     NaN                    NaN
# _spot                                 91.5                   91.5
# option_type                             -1                     -1
# option_exposure       OptionExposure.SHORT   OptionExposure.SHORT
# valuation               December 2nd, 2023     December 2nd, 2023
# expiration             December 29th, 2023    December 29th, 2023
# premium                               0.43                   0.63
# K                                     89.0                   90.0
# ivol                                0.1814                  0.178
# contract_id             TLT231229P00089000     TLT231229P00090000
# rfr                                   0.05                   0.05
# npv_market                         0.71572               1.000052
# npv_historical                    0.055905               0.171248
# hvol2                             0.153237               0.153237
# npv_historical_2std               0.498133               0.773998
# hvol_garch                        0.051372               0.051372
# npv_garch_iv                      0.005451               0.043667
# calc_iv                           0.144178                0.13643
# delta                             -0.25808              -0.335154
# gamma                             0.072824               0.084095
# theta                            -8.814912              -9.570402
#
#                         TLT231229P00091000     TLT231229P00092000
# Last Trade Date      2023-12-01 3:59PM EST  2023-12-01 3:53PM EST  \
# Strike                                91.0                   92.0
# Last Price                            0.92                   1.27
# Bid                                    0.9                   1.25
# Ask                                   0.93                   1.28
# Change                               -0.66                  -0.89
# % Change                           -41.77%                -41.20%
# Volume                                1864                    552
# Open Interest                         2933                   1647
# Implied Volatility                  17.51%                 17.24%
# Expiration Date                 2023-12-29             2023-12-29
# Expiration_dt          2023-12-29 00:00:00    2023-12-29 00:00:00
# Market_IV                           0.1751                 0.1724
# price_ts                               NaN                    NaN
# df                                     NaN                    NaN
# _spot                                 91.5                   91.5
# option_type                             -1                     -1
# option_exposure       OptionExposure.SHORT   OptionExposure.SHORT
# valuation               December 2nd, 2023     December 2nd, 2023
# expiration             December 29th, 2023    December 29th, 2023
# premium                                0.9                   1.25
# K                                     91.0                   92.0
# ivol                                0.1751                 0.1724
# contract_id             TLT231229P00091000     TLT231229P00092000
# rfr                                   0.05                   0.05
# npv_market                        1.369186               1.829379
# npv_historical                    0.430372               0.892747
# hvol2                             0.153237               0.153237
# npv_historical_2std                 1.1566               1.639656
# hvol_garch                        0.051372               0.051372
# npv_garch_iv                      0.209345               0.658944
# calc_iv                           0.126947               0.113865
# delta                            -0.422897              -0.517721
# gamma                             0.092602               0.097135
# theta                            -9.882001              -9.625402
#
#                         TLT231229P00093000     TLT231229P00094000
# Last Trade Date      2023-12-01 3:51PM EST  2023-12-01 3:48PM EST  \
# Strike                                93.0                   94.0
# Last Price                            1.74                   2.28
# Bid                                    1.7                   2.27
# Ask                                   1.74                   2.31
# Change                               -1.21                  -1.12
# % Change                           -41.02%                -32.94%
# Volume                                 217                     22
# Open Interest                          676                    310
# Implied Volatility                  17.20%                 17.35%
# Expiration Date                 2023-12-29             2023-12-29
# Expiration_dt          2023-12-29 00:00:00    2023-12-29 00:00:00
# Market_IV                            0.172                 0.1735
# price_ts                               NaN                    NaN
# df                                     NaN                    NaN
# _spot                                 91.5                   91.5
# option_type                             -1                     -1
# option_exposure       OptionExposure.SHORT   OptionExposure.SHORT
# valuation               December 2nd, 2023     December 2nd, 2023
# expiration             December 29th, 2023    December 29th, 2023
# premium                                1.7                   2.27
# K                                     93.0                   94.0
# ivol                                 0.172                 0.1735
# contract_id             TLT231229P00093000     TLT231229P00094000
# rfr                                   0.05                   0.05
# npv_market                        2.405812               3.090669
# npv_historical                    1.586579                    2.5
# hvol2                             0.153237               0.153237
# npv_historical_2std               2.226519               2.924382
# hvol_garch                        0.051372               0.051372
# npv_garch_iv                           1.5                    2.5
# calc_iv                           0.092731                    NaN
# delta                            -0.613555              -0.702645
# gamma                             0.095677               0.088935
# theta                            -8.921598              -7.837712
#
#                         TLT231229P00095000     TLT231229P00096000
# Last Trade Date      2023-12-01 1:39PM EST  2023-12-01 2:44PM EST  \
# Strike                                95.0                   96.0
# Last Price                            2.88                   3.86
# Bid                                   2.92                   3.65
# Ask                                   2.98                   3.75
# Change                               -1.07                  -0.51
# % Change                           -27.09%                -11.67%
# Volume                                 530                      7
# Open Interest                         1841                   9857
# Implied Volatility                  17.65%                 18.26%
# Expiration Date                 2023-12-29             2023-12-29
# Expiration_dt          2023-12-29 00:00:00    2023-12-29 00:00:00
# Market_IV                           0.1765                 0.1826
# price_ts                               NaN                    NaN
# df                                     NaN                    NaN
# _spot                                 91.5                   91.5
# option_type                             -1                     -1
# option_exposure       OptionExposure.SHORT   OptionExposure.SHORT
# valuation               December 2nd, 2023     December 2nd, 2023
# expiration             December 29th, 2023    December 29th, 2023
# premium                               2.92                   3.65
# K                                     95.0                   96.0
# ivol                                0.1765                 0.1826
# contract_id             TLT231229P00095000     TLT231229P00096000
# rfr                                   0.05                   0.05
# npv_market                        3.867803               4.729201
# npv_historical                         3.5                    4.5
# hvol2                             0.153237               0.153237
# npv_historical_2std               3.712932               4.579834
# hvol_garch                        0.051372               0.051372
# npv_garch_iv                           3.5                    4.5
# calc_iv                                NaN                    NaN
# delta                            -0.779647              -0.838782
# gamma                             0.078853               0.067198
# theta                            -6.522784              -5.305431
#
#                         TLT231229P00097000
# Last Trade Date      2023-11-30 2:47PM EST
# Strike                                97.0
# Last Price                            4.55
# Bid                                   4.45
# Ask                                    4.6
# Change                               -1.43
# % Change                           -23.91%
# Volume                                   6
# Open Interest                        10556
# Implied Volatility                  19.24%
# Expiration Date                 2023-12-29
# Expiration_dt          2023-12-29 00:00:00
# Market_IV                           0.1924
# price_ts                               NaN
# df                                     NaN
# _spot                                 91.5
# option_type                             -1
# option_exposure       OptionExposure.SHORT
# valuation               December 2nd, 2023
# expiration             December 29th, 2023
# premium                               4.45
# K                                     97.0
# ivol                                0.1924
# contract_id             TLT231229P00097000
# rfr                                   0.05
# npv_market                        5.651611
# npv_historical                         5.5
# hvol2                             0.153237
# npv_historical_2std               5.513257
# hvol_garch                        0.051372
# npv_garch_iv                           5.5
# calc_iv                                NaN
# delta                            -0.879369
# gamma                             0.056228
# theta                            -4.407502

# %%
from pyfi.core.options.strategies.vertical_put_spread import VerticalPutSpread
from pyfi.base.retrievers import options
from pyfi.core.options.options import Chain, Contract, OptionType, OptionExposure
import QuantLib as ql
from datetime import datetime
today = datetime.today()

leg_long = Contract(ticker='TLT', option_type = OptionType.PUT, option_exposure = OptionExposure.SHORT,
                valuation=ql.Date(today.day, today.month, today.year), expiration=ql.Date(22, 12, 2023), 
                premium=4, spot=None, K=90.5, ivol=None) #contract_id=self.contract_id

leg_short = Contract(ticker='TLT', option_type = OptionType.PUT, option_exposure = OptionExposure.LONG,
                valuation=ql.Date(today.day, today.month, today.year), expiration=ql.Date(22, 12, 2023), 
                premium=2, spot=None, K=85.5, ivol=None) #contract_id=self.contract_id

vps = VerticalPutSpread(clsLong=leg_long, clsShort=leg_short)
vps.plot()
print('max profit:', vps.max_profit)
print('max loss:', vps.max_loss)
print('pl ratio:', vps.pl_ratio,  'pl odds', f"{1/vps.pl_ratio}:1")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# {'price_ts': Date
# 2023-01-03    101.459999
# 2023-01-04    102.849998
# 2023-01-05    103.279999
# 2023-01-06    105.180000
# 2023-01-09    105.739998
#                  ...
# 2023-11-27     91.300003
# 2023-11-28     91.480003
# 2023-11-29     92.629997
# 2023-11-30     91.559998
# 2023-12-01     92.989998
# Name: Close, Length: 231, dtype: float64, 'df': Date
# 2023-01-03    101.459999
# 2023-01-04    102.849998
# 2023-01-05    103.279999
# 2023-01-06    105.180000
# 2023-01-09    105.739998
#                  ...
# 2023-11-27     91.300003
# 2023-11-28     91.480003
# 2023-11-29     92.629997
# 2023-11-30     91.559998
# 2023-12-01     92.989998
# Name: Close, Length: 231, dtype: float64, '_spot': 92.98999786376953, 'option_type': <OptionType.PUT: -1>, 'option_exposure': <OptionExposure.SHORT: 'Bid'>, 'valuation': Date(2,12,2023), 'expiration': Date(22,12,2023), 'premium': 4, 'K': 90.5, 'ivol': None, 'contract_id': None, 'rfr': 0.05}
# [*********************100%%**********************]  1 of 1 completed
# {'price_ts': Date
# 2023-01-03    101.459999
# 2023-01-04    102.849998
# 2023-01-05    103.279999
# 2023-01-06    105.180000
# 2023-01-09    105.739998
#                  ...
# 2023-11-27     91.300003
# 2023-11-28     91.480003
# 2023-11-29     92.629997
# 2023-11-30     91.559998
# 2023-12-01     92.989998
# Name: Close, Length: 231, dtype: float64, 'df': Date
# 2023-01-03    101.459999
# 2023-01-04    102.849998
# 2023-01-05    103.279999
# 2023-01-06    105.180000
# 2023-01-09    105.739998
#                  ...
# 2023-11-27     91.300003
# 2023-11-28     91.480003
# 2023-11-29     92.629997
# 2023-11-30     91.559998
# 2023-12-01     92.989998
# Name: Close, Length: 231, dtype: float64, '_spot': 92.98999786376953, 'option_type': <OptionType.PUT: -1>, 'option_exposure': <OptionExposure.LONG: 'Ask'>, 'valuation': Date(2,12,2023), 'expiration': Date(22,12,2023), 'premium': 2, 'K': 85.5, 'ivol': None, 'contract_id': None, 'rfr': 0.05}
# max profit: 200
# max loss: 300.0
# pl ratio: 0.6666666666666666 pl odds 1.5:1
